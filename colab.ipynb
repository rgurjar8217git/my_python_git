# %% [markdown]
# <a href="https://colab.research.google.com/github/rgurjar8217git/my_python_git/blob/main/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter an number :"))
b = int(input("Enter another number:"))
c = a + b
print(c)
# Out:
# Enter an number :67
# Enter another number:70
# 137
