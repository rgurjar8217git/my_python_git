# %% [markdown]
# <a href="https://colab.research.google.com/github/rgurjar8217git/my_python_git/blob/main/Module3_Activity3_1_Pandas_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 3 – Activity 3.1
# ## Pandas Hands-on Lab (5 Marks)
#
# **Instructions:**
# - Complete all tasks
# - Write code in the given cells
# - Run each cell and show outputs
# - Add comments wherever required
# - Submit the completed notebook (PDF) on LMS
#
# **Name:** _Rahul gurajr
# **Roll No.:** __BETN1AI25039
# **Course:** Data Analytics Using Python (AIL0202)

# %%
# Import required libraries
# Write code to import pandas and numpy
import pandas as pd
import numpy as np

# %% [markdown]
# ## Task 1: Data Creation & Loading (1 Mark)
# Dataset:
#     'Name': ['Aman','Riya','Rahul','Sneha','Karan'],
#     'Department': ['IT','HR','IT','Finance','HR'],
#     'Salary': [50000,60000,55000,65000,52000]

# %%
# Create:
# 1. A Pandas Series from a list of 5 elements
# 2. A DataFrame with columns: Name, Department, Salary
# 3. Write a dataset using (any one): CSV / Excel / JSON
import pandas as pd

my_list = [10, 20, 30, 40, 50]
series_data = pd.Series(my_list)

data = {
    'Name': ['Aman', 'Riya', 'Rahul', 'Sneha', 'Karan'],
    'Department': ['IT', 'HR', 'IT', 'Finance', 'HR'],
    'Salary': [50000, 60000, 55000, 65000, 52000]
}
df = pd.DataFrame(data)

df.to_csv('employee_dataset.csv', index=False)

print("Pandas Series:\n", series_data)
print("\nDataFrame:\n", df)
# Out:
# Pandas Series:
#  0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# DataFrame:
#      Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
# 3  Sneha    Finance   65000
# 4  Karan         HR   52000

# %% [markdown]
# ## Task 2: Data Exploration (1 Mark)

# %%
# Perform:
# Display first 3 rows
# Display dataset information
# Display statistical summary
import pandas as pd

print("--- First 3 Rows ---")
print(df.head(3))
print("\n--- Dataset Information ---")
df.info()

print("\n--- Statistical Summary ---")
print(df.describe())
# Out:
# --- First 3 Rows ---
#     Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
#
# --- Dataset Information ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Department  5 non-null      object
#  2   Salary      5 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
#
# --- Statistical Summary ---
#              Salary
# count      5.000000
# mean   56400.000000
# std     6107.372594
# min    50000.000000
# 25%    52000.000000
# 50%    55000.000000
# 75%    60000.000000
# max    65000.000000

# %% [markdown]
# ## Task 3: Indexing, Filtering & Sorting (1 Mark)

# %%
# Perform:
# 1. Extract first 3 rows using .loc[]

import pandas as pd

first_three_rows = df.loc[0:2]

print(first_three_rows)
# 2. Extract Salary column using .iloc[]
salary_column = df.iloc[:,1]

print(salary_column)
# 3. Filter employees with Salary > 55000
high_salary_df = df[df['Salary'] > 55000]

print(high_salary_df)
# 4. Sort dataset by Salary (descending)
sorted_df = df.sort_values(by='Salary', ascending=False)

print(sorted_df)
# Out:
#     Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
# 0         IT
# 1         HR
# 2         IT
# 3    Finance
# 4         HR
# Name: Department, dtype: object
#     Name Department  Salary
# 1   Riya         HR   60000
# 3  Sneha    Finance   65000
#     Name Department  Salary
# 3  Sneha    Finance   65000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
# 4  Karan         HR   52000
# 0   Aman         IT   50000

# %% [markdown]
# ## Task 4: Group-by & Aggregation (1 Mark)

# %%
# Perform:

import pandas as pd
# 1. Find average salary department-wise

avg_salary = df.groupby('Department')['Salary'].mean()
print(avg_salary)
# 2. Find total and count of employees per department
dept_stats = df.groupby('Department')['Salary'].agg(['sum', 'count'])
print(dept_stats)
# Out:
# Department
# Finance    65000.0
# HR         56000.0
# IT         52500.0
# Name: Salary, dtype: float64
#                sum  count
# Department
# Finance      65000      1
# HR          112000      2
# IT          105000      2

# %% [markdown]
# ## Task 5: Data Cleaning & Time-Series (1 Mark)

# %%
# Given:
# df['Joining_Date'] = ['2022-01-10','2021-07-15','2023-03-12','2020-11-05','2022-05-20']

# Perform:
import pandas as pd
data = {'Joining_Date': ['2022-01-10','2021-07-15','2023-03-12','2020-11-05','2022-05-20']}
df = pd.DataFrame(data)
# 1.  Convert Joining_Date to datetime

df['Joining_Date'] = pd.to_datetime(df['Joining_Date'])
# 2. Extract Year and Month
df['Year'] = df['Joining_Date'].dt.year
df['Month'] = df['Joining_Date'].dt.month
# 3. Identify duplicate rows
print(df[df.duplicated()])
duplicates = df.duplicated()
# 4. Remove duplicate rows
df = df.drop_duplicates()
print(df)
# Out:
# Empty DataFrame
# Columns: [Joining_Date, Year, Month]
# Index: []
#   Joining_Date  Year  Month
# 0   2022-01-10  2022      1
# 1   2021-07-15  2021      7
# 2   2023-03-12  2023      3
# 3   2020-11-05  2020     11
# 4   2022-05-20  2022      5
